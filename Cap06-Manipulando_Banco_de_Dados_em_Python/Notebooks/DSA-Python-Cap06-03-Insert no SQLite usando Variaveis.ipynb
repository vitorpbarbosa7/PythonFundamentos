# %% [markdown]
# # <font color='blue'>Data Science Academy - Python Fundamentos - Capítulo 6</font>
#
# ## Download: http://github.com/dsacademybr

# %% [markdown]
# ### Inserindo Dados com Variáveis

# %%
import sqlite3
import random
#Puxar os dois juntos para funcionar time e datetime
import time
import datetime
 
# Criando uma conexão
conn = sqlite3.connect('dsa.db')   

# Criando um cursor
c = conn.cursor()
 
# Função para criar uma tabela
def create_table():
    c.execute('CREATE TABLE IF NOT EXISTS produtos(id INTEGER PRIMARY KEY AUTOINCREMENT NOT NULL, date TEXT, '\
              'prod_name TEXT, valor REAL)')
    
# # Função para inserir uma linha
# def data_insert():
#     c.execute("INSERT INTO produtos VALUES('2018-05-02 12:34:45', 'Teclado', 130.00 )")
#     conn.commit()
#     c.close()
#     conn.close()
    
# Usando variáveis para inserir dados    
def data_insert_var():
    new_date = datetime.datetime.now()
    #Inserir uma série de monitores
    new_prod_name = 'Monitor' #Podia puxar de um outro banco de dados... kkk
    new_valor = random.randrange(0,1000000)
    #Quem define a inserção no banco de dados é a linguagem sql não a linguagem python 
    #INSERT INTO faz parte da linguagem sql 
    c.execute("INSERT INTO produtos (date, prod_name, valor) VALUES (?, ?, ?)", (new_date, new_prod_name, new_valor))
    conn.commit() #gravar, se não colocar essa linha, não grava, simples

# %%
# Gerando valores e inserindo na tabela
# Maneira de executar 10 vezes a função 
for i in range(10):
    data_insert_var()
    time.sleep(1)

# %%
conexao = sqlite3.connect('dsa.db')

cursor = conexao.cursor()

# %%
#Sem visualizar o resultado fica difícil né querido 

cursor.execute('select * from produtos')

dados = cursor.fetchall()

for registro in dados:
    print(registro)
    print('id: %d, data: %s, Nome do Produto: %s, Valor em R$: %d \n' %(registro))
# Out:
# (10, '2018-05-02 14:32:11', 'Teclado', 90.0)
# id: 10, data: 2018-05-02 14:32:11, Nome do Produto: Teclado, Valor em R$: 90
#
# (11, '2019-11-26 21:12:37.035320', 'Monitor', 65.0)
# id: 11, data: 2019-11-26 21:12:37.035320, Nome do Produto: Monitor, Valor em R$: 65
#
# (12, '2019-11-26 21:12:38.294443', 'Monitor', 92.0)
# id: 12, data: 2019-11-26 21:12:38.294443, Nome do Produto: Monitor, Valor em R$: 92
#
# (13, '2019-11-26 21:12:39.489418', 'Monitor', 63.0)
# id: 13, data: 2019-11-26 21:12:39.489418, Nome do Produto: Monitor, Valor em R$: 63
#
# (14, '2019-11-26 21:12:40.649730', 'Monitor', 57.0)
# id: 14, data: 2019-11-26 21:12:40.649730, Nome do Produto: Monitor, Valor em R$: 57
#
# (15, '2019-11-26 21:12:41.756625', 'Monitor', 94.0)
# id: 15, data: 2019-11-26 21:12:41.756625, Nome do Produto: Monitor, Valor em R$: 94
#
# (16, '2019-11-26 21:12:42.874448', 'Monitor', 94.0)
# id: 16, data: 2019-11-26 21:12:42.874448, Nome do Produto: Monitor, Valor em R$: 94
#
# ...

# %%
# Encerrando a conexão
c.close()
conn.close() #Fechar conexão para evitar problemas de consumir recursos e questão de segurança

# %% [markdown]
# # Fim

# %% [markdown]
# ### Obrigado - Data Science Academy - <a href="http://facebook.com/dsacademybr">facebook.com/dsacademybr</a>
